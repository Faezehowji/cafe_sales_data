# %% [markdown]
# # Cafe Sale Cleaning Project
# This project analyzes a cafe sales dataset containing synthetic sales transaction data from a cafe. The key objective is to clean and preprocess the data, then analyze and visualize the quantity of each item sold. (In this notebook, I analyze and visualize sales data to gain insights into customer purchasing behavior. The dataset includes information about different items sold, quantities, prices, transaction dates, and payment methods.)
#
# **Goals of this project:**
#
# * Clean and standardize raw sales data by handling missing or erroneous values.
# * Impute missing values using logical estimates derived from existing data for improved accuracy.
# * Visualize the distribution of quantities sold across different product categories.
#
# The dataset was obtained from Kaggle, available at: https://www.kaggle.com/datasets/ahmedmohamed2003/cafe-sales-dirty-data-for-cleaning-training/data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# We begin by loading the dataset from a CSV file and then display the first 10 rows to get an initial look at the data.

# %%
df= pd.read_csv('../data/dirty_cafe.csv')
df.head(10)
# Out:
#   Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0    TXN_1961373    Coffee        2            2.0         4.0
# 1    TXN_4977031      Cake        4            3.0        12.0
# 2    TXN_4271903    Cookie        4            1.0       ERROR
# 3    TXN_7034554     Salad        2            5.0        10.0
# 4    TXN_3160411    Coffee        2            2.0         4.0
# 5    TXN_2602893  Smoothie        5            4.0        20.0
# 6    TXN_4433211   UNKNOWN        3            3.0         9.0
# 7    TXN_6699534  Sandwich        4            4.0        16.0
# 8    TXN_4717867       NaN        5            3.0        15.0
# 9    TXN_2064365  Sandwich        5            4.0        20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11
# 5     Credit Card       NaN       2023-03-31
# 6           ERROR  Takeaway       2023-10-06
# 7            Cash   UNKNOWN       2023-10-28
# 8             NaN  Takeaway       2023-07-28
# 9             NaN  In-store       2023-12-31

# %% [markdown]
# To get a quick overview of the dataset, we use df.info(). This provides essential information about the dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %% [markdown]
# To explore all the unique values in the Item column.

# %%
df['Item'].unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
#        'Sandwich', nan, 'ERROR', 'Juice', 'Tea'], dtype=object)

# %% [markdown]
# We clean the Item column by replacing inconsistent entries with proper missing values (NaN), and then filling them with a unified lable 'Unknown'.

# %%
df['Item'] = df['Item'].replace (['UNKNOWN', 'ERROR','nan'], np.nan)
df['Item'] = df['Item'].fillna('Unknown')
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %% [markdown]
# To explore all the unique values in the Quantity column.

# %%
df['Quantity'].unique()
# Out:
# array(['2', '4', '5', '3', '1', 'ERROR', 'UNKNOWN', nan], dtype=object)

# %% [markdown]
# To get a quick overview of the dataset and to check if there are any Non-Null values in Columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              10000 non-null  object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %% [markdown]
# We replace the inconsistent entries with proper missing values (NaN), and then convert each column to numeric. Any values that can't be converted will also become NaN. We use the mathematical relationships to fill in the missing values where possible.

# %%
cols = ['Quantity','Price Per Unit','Total Spent']

for col  in cols:
    df[col]= df[col].replace(['UNKNOWN','ERROR','NaN'], np.nan)
for col in cols:
    df[col]= pd.to_numeric(df[col], errors='coerce')

#Quantity
mask = df['Quantity'].isna()
df.loc[mask, 'Quantity'] = df.loc[mask, 'Total Spent'] / df.loc[mask, 'Price Per Unit']

#Price Per Unit
mask = df['Price Per Unit'].isna()
df.loc[mask, 'Price Per Unit'] = df.loc[mask, 'Total Spent'] / df.loc[mask, 'Quantity']

#Total Spent
mask = df['Total Spent'].isna()
df.loc[mask, 'Total Spent'] = df.loc[mask, 'Price Per Unit'] * df.loc[mask, 'Quantity']

df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          4.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %% [markdown]
# We create a dictionary called Item_Prices that maps each unique item to its corresponding unit price.

# %%
Item_Prices = (
    df[['Item', 'Price Per Unit']]
    .dropna()
    .drop_duplicates()
    .set_index('Item')
    .squeeze()
    .to_dict())
Item_Prices
# Out:
# {'Coffee': 2.0,
#  'Cake': 3.0,
#  'Cookie': 1.0,
#  'Salad': 5.0,
#  'Smoothie': 4.0,
#  'Unknown': 4.0,
#  'Sandwich': 4.0,
#  'Juice': 3.0,
#  'Tea': 1.5}

# %% [markdown]
# We identify rows where **two or more values are missing** among the key numerical columns: 'Quantity', 'Price Per Unit', and 'Total Spent'.

# %%
cols = ['Quantity', 'Price Per Unit', 'Total Spent']

rows_with_2_or_more_nans = df[df[cols].isna().sum(axis=1) >= 2]

rows_with_2_or_more_nans
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 65      TXN_4987129  Sandwich       3.0             NaN          NaN
# 236     TXN_8562645     Salad       NaN             5.0          NaN
# 278     TXN_3229409     Juice       NaN             3.0          NaN
# 629     TXN_9289174      Cake       NaN             NaN         12.0
# 641     TXN_2962976     Juice       NaN             3.0          NaN
# 738     TXN_8696094  Sandwich       NaN             4.0          NaN
# 912     TXN_1575608  Sandwich       NaN             NaN         20.0
# 1008    TXN_7225428       Tea       NaN             NaN          3.0
# 1436    TXN_7590801       Tea       NaN             NaN          6.0
# 1482    TXN_3593060  Smoothie       NaN             NaN         16.0
# 1674    TXN_9367492       Tea       2.0             NaN          NaN
# 1761    TXN_3611851   Unknown       4.0             NaN          NaN
# 2229    TXN_8498613  Sandwich       2.0             NaN          NaN
# 2289    TXN_7524977   Unknown       4.0             NaN          NaN
# 2330    TXN_3849488     Salad       NaN             NaN          5.0
# 2585    TXN_1259340       Tea       3.0             NaN          NaN
# 2796    TXN_9188692      Cake       NaN             3.0          NaN
# 3162    TXN_3577949      Cake       3.0             NaN          NaN
# 3203    TXN_4565754  Smoothie       NaN             4.0          NaN
# 3224    TXN_6297232    Coffee       NaN             2.0          NaN
# 3401    TXN_3251829       Tea       NaN             1.5          NaN
# 3598    TXN_2857444  Smoothie       1.0             NaN          NaN
# 3635    TXN_6177081    Cookie       NaN             NaN          1.0
# 3673    TXN_6500126  Smoothie       2.0             NaN          NaN
# 3779    TXN_7376255   Unknown       NaN             NaN         25.0
# 4021    TXN_6424202    Cookie       2.0             NaN          NaN
# 4152    TXN_9646000   Unknown       2.0             NaN          NaN
# 4257    TXN_6470865    Coffee       NaN             2.0          NaN
# 5639    TXN_6206792       Tea       NaN             NaN          6.0
# 5841    TXN_5884081    Cookie       NaN             1.0          NaN
# 5845    TXN_8388462  Smoothie       NaN             NaN          8.0
# 6225    TXN_6859249    Cookie       NaN             NaN          2.0
# 6661    TXN_5308047    Cookie       NaN             NaN          1.0
# 6674    TXN_3071092    Coffee       NaN             NaN          4.0
# 7029    TXN_4628338    Coffee       NaN             2.0          NaN
# 7035    TXN_8872984     Salad       5.0             NaN          NaN
# 7230    TXN_5118799    Cookie       2.0             NaN          NaN
# 7244    TXN_2253622  Sandwich       5.0             NaN          NaN
# 7297    TXN_9944500  Smoothie       NaN             4.0          NaN
# 7568    TXN_3705445    Cookie       5.0             NaN          NaN
# 7597    TXN_1082717   Unknown       NaN             NaN          9.0
# 7686    TXN_6905143    Coffee       5.0             NaN          NaN
# 8021    TXN_2428781     Salad       NaN             5.0          NaN
# 8128    TXN_6105807  Smoothie       3.0             NaN          NaN
# 8443    TXN_2023651  Sandwich       NaN             4.0          NaN
# 8465    TXN_9669616    Coffee       NaN             2.0          NaN
# 8479    TXN_1547245  Sandwich       NaN             4.0          NaN
# 8497    TXN_1525583  Sandwich       3.0             NaN          NaN
# 8574    TXN_2546684     Juice       NaN             3.0          NaN
# 8669    TXN_7764304      Cake       NaN             NaN          3.0
# 8732    TXN_4550558    Cookie       NaN             1.0          NaN
# 8975    TXN_8077367       Tea       NaN             NaN          7.5
# 9212    TXN_7322317       Tea       1.0             NaN          NaN
# 9464    TXN_5744797      Cake       NaN             NaN          3.0
# 9590    TXN_9924732  Sandwich       NaN             4.0          NaN
# 9819    TXN_1208561   Unknown       NaN             NaN         20.0
# 9869    TXN_1975184    Coffee       NaN             2.0          NaN
# 9893    TXN_3809533     Juice       2.0             NaN          NaN
#
#       Payment Method  Location Transaction Date
# 65               NaN  In-store       2023-10-20
# 236              NaN  In-store       2023-05-18
# 278             Cash  Takeaway       2023-04-15
# 629   Digital Wallet  In-store       2023-12-30
# 641              NaN       NaN       2023-03-17
# 738              NaN  Takeaway       2023-05-14
# 912            ERROR  Takeaway       2023-01-05
# 1008     Credit Card  Takeaway       2023-03-07
# 1436            Cash  Takeaway            ERROR
# 1482            Cash       NaN       2023-03-05
# 1674            Cash  In-store       2023-06-19
# 1761     Credit Card       NaN       2023-02-09
# 2229             NaN       NaN       2023-11-08
# 2289           ERROR       NaN       2023-12-09
# 2330             NaN  In-store       2023-03-01
# 2585  Digital Wallet       NaN       2023-02-24
# 2796     Credit Card       NaN       2023-12-01
# 3162           ERROR  Takeaway       2023-04-25
# 3203  Digital Wallet  Takeaway       2023-10-06
# 3224             NaN       NaN       2023-04-07
# 3401  Digital Wallet  In-store       2023-07-25
# 3598            Cash  Takeaway       2023-05-10
# 3635            Cash     ERROR       2023-07-26
# 3673             NaN   UNKNOWN              NaN
# 3779             NaN  In-store       2023-05-27
# 4021     Credit Card  In-store       2023-11-20
# 4152             NaN  In-store       2023-12-14
# 4257  Digital Wallet  Takeaway       2023-09-18
# 5639     Credit Card       NaN       2023-10-13
# 5841  Digital Wallet  In-store       2023-07-05
# 5845         UNKNOWN  Takeaway       2023-08-19
# 6225             NaN   UNKNOWN              NaN
# 6661     Credit Card       NaN       2023-10-28
# 6674           ERROR       NaN       2023-09-08
# 7029            Cash       NaN       2023-12-25
# 7035     Credit Card  In-store       2023-08-23
# 7230            Cash  Takeaway       2023-04-23
# 7244  Digital Wallet  Takeaway       2023-09-30
# 7297            Cash  In-store       2023-01-03
# 7568            Cash  In-store       2023-09-13
# 7597  Digital Wallet  In-store       2023-12-13
# 7686            Cash     ERROR       2023-08-09
# 8021             NaN  In-store       2023-05-09
# 8128     Credit Card  Takeaway       2023-01-18
# 8443            Cash  In-store       2023-05-25
# 8465             NaN     ERROR       2023-06-03
# 8479             NaN  Takeaway       2023-09-11
# 8497            Cash  Takeaway       2023-05-20
# 8574  Digital Wallet  Takeaway       2023-04-08
# 8669     Credit Card  Takeaway       2023-01-09
# 8732     Credit Card  In-store       2023-08-04
# 8975     Credit Card       NaN       2023-02-27
# 9212             NaN       NaN       2023-03-16
# 9464            Cash  In-store       2023-12-20
# 9590     Credit Card  In-store       2023-01-18
# 9819     Credit Card       NaN       2023-08-19
# 9869  Digital Wallet       NaN       2023-01-15
# 9893  Digital Wallet  Takeaway       2023-02-02

# %% [markdown]
# We fill in missing values in the 'Price Per Unit' column based on the item name. These values are likely derived from known standard prices for each item.

# %%
df.loc[(df['Item'] == 'Sandwich') & (df['Price Per Unit'].isna()), 'Price Per Unit'] = 4.0
df.loc[(df['Item'] == 'Coffee') & (df['Price Per Unit'].isna()), 'Price Per Unit'] = 2.0
df.loc[(df['Item'] == 'Cake') & (df['Price Per Unit'].isna()), 'Price Per Unit'] = 3.0
df.loc[(df['Item'] == 'Cookie') & (df['Price Per Unit'].isna()), 'Price Per Unit'] = 1.0
df.loc[(df['Item'] == 'Salad') & (df['Price Per Unit'].isna()), 'Price Per Unit'] = 5.0
df.loc[(df['Item'] == 'Smoothie') & (df['Price Per Unit'].isna()), 'Price Per Unit'] = 4.0
df.loc[(df['Item'] == 'Juice') & (df['Price Per Unit'].isna()), 'Price Per Unit'] = 3.0
df.loc[(df['Item'] == 'Tea') & (df['Price Per Unit'].isna()), 'Price Per Unit'] = 1.5

df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          4.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %% [markdown]
# we recheck the dataset to identify any rows that **still have two or more missing values** in the key numeric columns.

# %%
cols = ['Quantity', 'Price Per Unit', 'Total Spent']

rows_with_2_or_more_nans = df[df[cols].isna().sum(axis=1) >= 2]

rows_with_2_or_more_nans
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 236     TXN_8562645     Salad       NaN             5.0          NaN
# 278     TXN_3229409     Juice       NaN             3.0          NaN
# 641     TXN_2962976     Juice       NaN             3.0          NaN
# 738     TXN_8696094  Sandwich       NaN             4.0          NaN
# 1761    TXN_3611851   Unknown       4.0             NaN          NaN
# 2289    TXN_7524977   Unknown       4.0             NaN          NaN
# 2796    TXN_9188692      Cake       NaN             3.0          NaN
# 3203    TXN_4565754  Smoothie       NaN             4.0          NaN
# 3224    TXN_6297232    Coffee       NaN             2.0          NaN
# 3401    TXN_3251829       Tea       NaN             1.5          NaN
# 3779    TXN_7376255   Unknown       NaN             NaN         25.0
# 4152    TXN_9646000   Unknown       2.0             NaN          NaN
# 4257    TXN_6470865    Coffee       NaN             2.0          NaN
# 5841    TXN_5884081    Cookie       NaN             1.0          NaN
# 7029    TXN_4628338    Coffee       NaN             2.0          NaN
# 7297    TXN_9944500  Smoothie       NaN             4.0          NaN
# 7597    TXN_1082717   Unknown       NaN             NaN          9.0
# 8021    TXN_2428781     Salad       NaN             5.0          NaN
# 8443    TXN_2023651  Sandwich       NaN             4.0          NaN
# 8465    TXN_9669616    Coffee       NaN             2.0          NaN
# 8479    TXN_1547245  Sandwich       NaN             4.0          NaN
# 8574    TXN_2546684     Juice       NaN             3.0          NaN
# 8732    TXN_4550558    Cookie       NaN             1.0          NaN
# 9590    TXN_9924732  Sandwich       NaN             4.0          NaN
# 9819    TXN_1208561   Unknown       NaN             NaN         20.0
# 9869    TXN_1975184    Coffee       NaN             2.0          NaN
#
#       Payment Method  Location Transaction Date
# 236              NaN  In-store       2023-05-18
# 278             Cash  Takeaway       2023-04-15
# 641              NaN       NaN       2023-03-17
# 738              NaN  Takeaway       2023-05-14
# 1761     Credit Card       NaN       2023-02-09
# 2289           ERROR       NaN       2023-12-09
# 2796     Credit Card       NaN       2023-12-01
# 3203  Digital Wallet  Takeaway       2023-10-06
# 3224             NaN       NaN       2023-04-07
# 3401  Digital Wallet  In-store       2023-07-25
# 3779             NaN  In-store       2023-05-27
# 4152             NaN  In-store       2023-12-14
# 4257  Digital Wallet  Takeaway       2023-09-18
# 5841  Digital Wallet  In-store       2023-07-05
# 7029            Cash       NaN       2023-12-25
# 7297            Cash  In-store       2023-01-03
# 7597  Digital Wallet  In-store       2023-12-13
# 8021             NaN  In-store       2023-05-09
# 8443            Cash  In-store       2023-05-25
# 8465             NaN     ERROR       2023-06-03
# 8479             NaN  Takeaway       2023-09-11
# 8574  Digital Wallet  Takeaway       2023-04-08
# 8732     Credit Card  In-store       2023-08-04
# 9590     Credit Card  In-store       2023-01-18
# 9819     Credit Card       NaN       2023-08-19
# 9869  Digital Wallet       NaN       2023-01-15

# %% [markdown]
# We remove any rows where the Item is labeled as 'Unknown', since these entries are too ambiguous to be useful for analysis.

# %%
df = df[~df['Item'].isin(['Unknown'])]
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          4.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %% [markdown]
# To ensure our data is now clean and usable, we perform one last check for rows that still have **two or more missing values** in the key numerical columns.

# %%
cols = ['Quantity', 'Price Per Unit', 'Total Spent']

rows_with_2_or_more_nans = df[df[cols].isna().sum(axis=1) >= 2]

rows_with_2_or_more_nans
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 236     TXN_8562645     Salad       NaN             5.0          NaN
# 278     TXN_3229409     Juice       NaN             3.0          NaN
# 641     TXN_2962976     Juice       NaN             3.0          NaN
# 738     TXN_8696094  Sandwich       NaN             4.0          NaN
# 2796    TXN_9188692      Cake       NaN             3.0          NaN
# 3203    TXN_4565754  Smoothie       NaN             4.0          NaN
# 3224    TXN_6297232    Coffee       NaN             2.0          NaN
# 3401    TXN_3251829       Tea       NaN             1.5          NaN
# 4257    TXN_6470865    Coffee       NaN             2.0          NaN
# 5841    TXN_5884081    Cookie       NaN             1.0          NaN
# 7029    TXN_4628338    Coffee       NaN             2.0          NaN
# 7297    TXN_9944500  Smoothie       NaN             4.0          NaN
# 8021    TXN_2428781     Salad       NaN             5.0          NaN
# 8443    TXN_2023651  Sandwich       NaN             4.0          NaN
# 8465    TXN_9669616    Coffee       NaN             2.0          NaN
# 8479    TXN_1547245  Sandwich       NaN             4.0          NaN
# 8574    TXN_2546684     Juice       NaN             3.0          NaN
# 8732    TXN_4550558    Cookie       NaN             1.0          NaN
# 9590    TXN_9924732  Sandwich       NaN             4.0          NaN
# 9869    TXN_1975184    Coffee       NaN             2.0          NaN
#
#       Payment Method  Location Transaction Date
# 236              NaN  In-store       2023-05-18
# 278             Cash  Takeaway       2023-04-15
# 641              NaN       NaN       2023-03-17
# 738              NaN  Takeaway       2023-05-14
# 2796     Credit Card       NaN       2023-12-01
# 3203  Digital Wallet  Takeaway       2023-10-06
# 3224             NaN       NaN       2023-04-07
# 3401  Digital Wallet  In-store       2023-07-25
# 4257  Digital Wallet  Takeaway       2023-09-18
# 5841  Digital Wallet  In-store       2023-07-05
# 7029            Cash       NaN       2023-12-25
# 7297            Cash  In-store       2023-01-03
# 8021             NaN  In-store       2023-05-09
# 8443            Cash  In-store       2023-05-25
# 8465             NaN     ERROR       2023-06-03
# 8479             NaN  Takeaway       2023-09-11
# 8574  Digital Wallet  Takeaway       2023-04-08
# 8732     Credit Card  In-store       2023-08-04
# 9590     Credit Card  In-store       2023-01-18
# 9869  Digital Wallet       NaN       2023-01-15

# %% [markdown]
# We fill in missing values in the Quantity column by using the **median quantity for each item**. Median improves data completeness while minimizing bias introduced by missing values.

# %%
df['Quantity'] = df.groupby('Item')['Quantity'].transform(
    lambda x: x.fillna(x.median())
)
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          4.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %% [markdown]
# Now we identify rows that have **exactly one missing value** among the key numeric columns: 'Quantity', 'Price Per Unit', and 'Total Spent'.

# %%
cols = ['Quantity', 'Price Per Unit', 'Total Spent']

rows_with_1_nan = df[df[cols].isna().sum(axis=1) == 1]

rows_with_1_nan
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 65      TXN_4987129  Sandwich       3.0             4.0          NaN
# 236     TXN_8562645     Salad       3.0             5.0          NaN
# 278     TXN_3229409     Juice       3.0             3.0          NaN
# 641     TXN_2962976     Juice       3.0             3.0          NaN
# 738     TXN_8696094  Sandwich       3.0             4.0          NaN
# 1674    TXN_9367492       Tea       2.0             1.5          NaN
# 2229    TXN_8498613  Sandwich       2.0             4.0          NaN
# 2585    TXN_1259340       Tea       3.0             1.5          NaN
# 2796    TXN_9188692      Cake       3.0             3.0          NaN
# 3162    TXN_3577949      Cake       3.0             3.0          NaN
# 3203    TXN_4565754  Smoothie       3.0             4.0          NaN
# 3224    TXN_6297232    Coffee       3.0             2.0          NaN
# 3401    TXN_3251829       Tea       3.0             1.5          NaN
# 3598    TXN_2857444  Smoothie       1.0             4.0          NaN
# 3673    TXN_6500126  Smoothie       2.0             4.0          NaN
# 4021    TXN_6424202    Cookie       2.0             1.0          NaN
# 4257    TXN_6470865    Coffee       3.0             2.0          NaN
# 5841    TXN_5884081    Cookie       3.0             1.0          NaN
# 7029    TXN_4628338    Coffee       3.0             2.0          NaN
# 7035    TXN_8872984     Salad       5.0             5.0          NaN
# 7230    TXN_5118799    Cookie       2.0             1.0          NaN
# 7244    TXN_2253622  Sandwich       5.0             4.0          NaN
# 7297    TXN_9944500  Smoothie       3.0             4.0          NaN
# 7568    TXN_3705445    Cookie       5.0             1.0          NaN
# 7686    TXN_6905143    Coffee       5.0             2.0          NaN
# 8021    TXN_2428781     Salad       3.0             5.0          NaN
# 8128    TXN_6105807  Smoothie       3.0             4.0          NaN
# 8443    TXN_2023651  Sandwich       3.0             4.0          NaN
# 8465    TXN_9669616    Coffee       3.0             2.0          NaN
# 8479    TXN_1547245  Sandwich       3.0             4.0          NaN
# 8497    TXN_1525583  Sandwich       3.0             4.0          NaN
# 8574    TXN_2546684     Juice       3.0             3.0          NaN
# 8732    TXN_4550558    Cookie       3.0             1.0          NaN
# 9212    TXN_7322317       Tea       1.0             1.5          NaN
# 9590    TXN_9924732  Sandwich       3.0             4.0          NaN
# 9869    TXN_1975184    Coffee       3.0             2.0          NaN
# 9893    TXN_3809533     Juice       2.0             3.0          NaN
#
#       Payment Method  Location Transaction Date
# 65               NaN  In-store       2023-10-20
# 236              NaN  In-store       2023-05-18
# 278             Cash  Takeaway       2023-04-15
# 641              NaN       NaN       2023-03-17
# 738              NaN  Takeaway       2023-05-14
# 1674            Cash  In-store       2023-06-19
# 2229             NaN       NaN       2023-11-08
# 2585  Digital Wallet       NaN       2023-02-24
# 2796     Credit Card       NaN       2023-12-01
# 3162           ERROR  Takeaway       2023-04-25
# 3203  Digital Wallet  Takeaway       2023-10-06
# 3224             NaN       NaN       2023-04-07
# 3401  Digital Wallet  In-store       2023-07-25
# 3598            Cash  Takeaway       2023-05-10
# 3673             NaN   UNKNOWN              NaN
# 4021     Credit Card  In-store       2023-11-20
# 4257  Digital Wallet  Takeaway       2023-09-18
# 5841  Digital Wallet  In-store       2023-07-05
# 7029            Cash       NaN       2023-12-25
# 7035     Credit Card  In-store       2023-08-23
# 7230            Cash  Takeaway       2023-04-23
# 7244  Digital Wallet  Takeaway       2023-09-30
# 7297            Cash  In-store       2023-01-03
# 7568            Cash  In-store       2023-09-13
# 7686            Cash     ERROR       2023-08-09
# 8021             NaN  In-store       2023-05-09
# 8128     Credit Card  Takeaway       2023-01-18
# 8443            Cash  In-store       2023-05-25
# 8465             NaN     ERROR       2023-06-03
# 8479             NaN  Takeaway       2023-09-11
# 8497            Cash  Takeaway       2023-05-20
# 8574  Digital Wallet  Takeaway       2023-04-08
# 8732     Credit Card  In-store       2023-08-04
# 9212             NaN       NaN       2023-03-16
# 9590     Credit Card  In-store       2023-01-18
# 9869  Digital Wallet       NaN       2023-01-15
# 9893  Digital Wallet  Takeaway       2023-02-02

# %% [markdown]
# We fill in missing values in the Total Spent column by calculating (Total Spent = Quantity * Price Per Unit). This is done only for rows where Total Spent is missing and both Quantity and Price Per Unit are available.

# %%
mask = df['Total Spent'].isna()
df.loc[mask, 'Total Spent'] = df.loc[mask, 'Quantity'] * df.loc[mask, 'Price Per Unit']

df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          4.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %% [markdown]
# To conduct a final check of all the unique values in the Quantity column.

# %%
df['Quantity'].unique()
# Out:
# array([2., 4., 5., 3., 1.])

# %%
df['Price Per Unit'].unique()
# Out:
# array([2. , 3. , 1. , 5. , 4. , 1.5])

# %%
df['Total Spent'].unique()
# Out:
# array([ 4. , 12. , 10. , 20. , 16. , 25. ,  8. ,  5. , 15. ,  6. ,  3. ,
#         2. ,  9. ,  1. ,  7.5,  4.5,  1.5])

# %%
df['Item'].unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'Sandwich',
#        'Juice', 'Tea'], dtype=object)

# %% [markdown]
# Now we explore all the unique values in the Payment Method column.

# %%
df['Payment Method'].unique()
# Out:
# array(['Credit Card', 'Cash', 'UNKNOWN', 'Digital Wallet', nan, 'ERROR'],
#       dtype=object)

# %% [markdown]
# This time, we replace invalid entries like 'UNKNOWN', 'ERROR', and 'nan' with actual (NaN) values first, then fill those missing values with the unified label 'Unknown'.

# %%
df['Payment Method'] = df['Payment Method'].replace (['UNKNOWN', 'ERROR','nan'], np.nan)
df['Payment Method'] = df['Payment Method'].fillna('Unknown')
df.head(10)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee       2.0             2.0          4.0
# 1     TXN_4977031      Cake       4.0             3.0         12.0
# 2     TXN_4271903    Cookie       4.0             1.0          4.0
# 3     TXN_7034554     Salad       2.0             5.0         10.0
# 4     TXN_3160411    Coffee       2.0             2.0          4.0
# 5     TXN_2602893  Smoothie       5.0             4.0         20.0
# 7     TXN_6699534  Sandwich       4.0             4.0         16.0
# 9     TXN_2064365  Sandwich       5.0             4.0         20.0
# 10    TXN_2548360     Salad       5.0             5.0         25.0
# 11    TXN_3051279  Sandwich       2.0             4.0          8.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          Unknown   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card       NaN       2023-03-31
# 7             Cash   UNKNOWN       2023-10-28
# 9          Unknown  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway            ERROR

# %% [markdown]
# To explore all the unique values in the Payment Method column.

# %%
df['Payment Method'].unique()
# Out:
# array(['Credit Card', 'Cash', 'Unknown', 'Digital Wallet'], dtype=object)

# %% [markdown]
# To get a quick overview of the dataset and to check if there are any Non-Null values in Columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9031 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    9031 non-null   object
#  1   Item              9031 non-null   object
#  2   Quantity          9031 non-null   float64
#  3   Price Per Unit    9031 non-null   float64
#  4   Total Spent       9031 non-null   float64
#  5   Payment Method    9031 non-null   object
#  6   Location          6086 non-null   object
#  7   Transaction Date  8888 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 635.0+ KB

# %% [markdown]
# We convert the Transaction Date column to proper datetime objects using pd.to_datetime.

# %%
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], errors='coerce')
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          4.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         Unknown   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %% [markdown]
# We check all the unique values in the Transaction Date column.

# %%
df['Transaction Date'].unique()
# Out:
# <DatetimeArray>
# ['2023-09-08 00:00:00', '2023-05-16 00:00:00', '2023-07-19 00:00:00',
#  '2023-04-27 00:00:00', '2023-06-11 00:00:00', '2023-03-31 00:00:00',
#  '2023-10-28 00:00:00', '2023-12-31 00:00:00', '2023-11-07 00:00:00',
#                  'NaT',
#  ...
#  '2023-10-06 00:00:00', '2023-11-11 00:00:00', '2023-06-07 00:00:00',
#  '2023-02-13 00:00:00', '2023-07-30 00:00:00', '2023-02-17 00:00:00',
#  '2023-05-20 00:00:00', '2023-11-05 00:00:00', '2023-03-27 00:00:00',
#  '2023-07-03 00:00:00']
# Length: 366, dtype: datetime64[ns]

# %% [markdown]
# In this step, we replace invalid entries like 'UNKNOWN', 'ERROR', and 'nan' with actual (NaN) values first, then fill those missing values with the unified label 'Unknown'.

# %%
df['Location'] = df['Location'].replace (['UNKNOWN', 'ERROR','nan'], np.nan)
df['Location'] = df['Location'].fillna('Unknown')
df.head(10)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee       2.0             2.0          4.0
# 1     TXN_4977031      Cake       4.0             3.0         12.0
# 2     TXN_4271903    Cookie       4.0             1.0          4.0
# 3     TXN_7034554     Salad       2.0             5.0         10.0
# 4     TXN_3160411    Coffee       2.0             2.0          4.0
# 5     TXN_2602893  Smoothie       5.0             4.0         20.0
# 7     TXN_6699534  Sandwich       4.0             4.0         16.0
# 9     TXN_2064365  Sandwich       5.0             4.0         20.0
# 10    TXN_2548360     Salad       5.0             5.0         25.0
# 11    TXN_3051279  Sandwich       2.0             4.0          8.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          Unknown   Unknown       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card   Unknown       2023-03-31
# 7             Cash   Unknown       2023-10-28
# 9          Unknown  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway              NaT

# %% [markdown]
# We aggregate the total quantity sold for each item and create a bar chart to visualize the sales distribution.

# %%
item_totals = df.groupby('Item')['Quantity'].sum().sort_values()

ax = item_totals.plot(kind='bar', figsize=(8,5))
plt.ylim(item_totals.min() * 0.95, item_totals.max() * 1.05)
plt.xlabel('Item')
plt.ylabel('Quantity Sold')
plt.title('Quantity Sold Per Item')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
